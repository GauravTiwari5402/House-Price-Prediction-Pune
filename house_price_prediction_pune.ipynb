# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Pune house data.csv")

# %%
df
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
df.head()
# Out:
#               area_type   availability       size  society total_sqft  bath  \
# 0  Super built-up  Area         19-Dec      2 BHK  Coomee        1056   2.0
# 1            Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600   5.0
# 2        Built-up  Area  Ready To Move      3 BHK      NaN       1440   2.0
# 3  Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521   3.0
# 4  Super built-up  Area  Ready To Move      2 BHK      NaN       1200   2.0
#
#    balcony   price    site_location
# 0      1.0   39.07      Alandi Road
# 1      3.0  120.00  Ambegaon Budruk
# 2      3.0   62.00       Anandnagar
# 3      1.0   95.00            Aundh
# 4      1.0   51.00       Aundh Road

# %%
df.tail()
# Out:
#                   area_type   availability       size  society total_sqft  \
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony  price         site_location
# 13315   4.0      0.0  231.0                Pashan
# 13316   5.0      NaN  400.0             Paud Road
# 13317   2.0      1.0   60.0              Pirangut
# 13318   4.0      1.0  488.0          Prabhat Road
# 13319   1.0      1.0   17.0  Pune Railway Station

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.size
# Out:
# 119880

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      13320 non-null  object
#  1   availability   13320 non-null  object
#  2   size           13304 non-null  object
#  3   society        7818 non-null   object
#  4   total_sqft     13320 non-null  object
#  5   bath           13247 non-null  float64
#  6   balcony        12711 non-null  float64
#  7   price          13320 non-null  float64
#  8   site_location  13319 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.isnull()
# Out:
#        area_type  availability   size  society  total_sqft   bath  balcony  \
# 0          False         False  False    False       False  False    False
# 1          False         False  False    False       False  False    False
# 2          False         False  False     True       False  False    False
# 3          False         False  False    False       False  False    False
# 4          False         False  False     True       False  False    False
# ...          ...           ...    ...      ...         ...    ...      ...
# 13315      False         False  False    False       False  False    False
# 13316      False         False  False     True       False  False     True
# 13317      False         False  False    False       False  False    False
# 13318      False         False  False    False       False  False    False
# 13319      False         False  False     True       False  False    False
#
#        price  site_location
# 0      False          False
# ...

# %%
df.isnull().sum()
# Out:
# area_type           0
# availability        0
# size               16
# society          5502
# total_sqft          0
# bath               73
# balcony           609
# price               0
# site_location       1
# dtype: int64

# %%
df[df['site_location'].isnull()].index.tolist()
# Out:
# [1728]

# %%
df[df['bath'].isnull()].index.tolist()
# Out:
# [56,
#  81,
#  224,
#  344,
#  579,
#  669,
#  702,
#  801,
#  941,
#  1264,
#  1267,
#  1686,
#  1724,
#  1765,
#  1775,
#  1852,
#  2264,
#  2500,
#  2563,
#  2809,
#  2862,
#  2944,
#  2998,
#  3370,
#  3544,
#  3598,
#  3862,
#  4210,
#  4346,
#  4843,
#  4894,
#  4995,
#  5333,
#  5464,
#  5498,
#  5747,
#  5918,
#  6256,
#  6343,
#  6423,
#  6481,
#  6636,
#  6719,
#  6778,
#  6873,
#  6971,
#  7398,
#  7623,
#  7680,
#  7921,
#  8020,
#  8056,
#  8275,
#  8289,
#  8306,
#  8472,
#  8565,
#  8703,
#  8783,
#  9129,
#  9437,
#  9699,
#  10330,
#  10553,
#  10634,
#  10726,
#  11019,
#  11297,
#  11496,
#  11569,
#  12768,
#  12861,
#  13240]

# %%
df['site_location'].drop([1728],axis=0)
# Out:
# 0                 Alandi Road
# 1             Ambegaon Budruk
# 2                  Anandnagar
# 3                       Aundh
# 4                  Aundh Road
#                  ...
# 13315                  Pashan
# 13316               Paud Road
# 13317                Pirangut
# 13318            Prabhat Road
# 13319    Pune Railway Station
# Name: site_location, Length: 13319, dtype: object

# %%
df.drop(index=1728,axis=0)
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
df.isnull().sum()
# Out:
# area_type           0
# availability        0
# size               16
# society          5502
# total_sqft          0
# bath               73
# balcony           609
# price               0
# site_location       1
# dtype: int64

# %%
df.dropna(how='any',axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type        0
# availability     0
# size             0
# society          0
# total_sqft       0
# bath             0
# balcony          0
# price            0
# site_location    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7496 entries, 0 to 13318
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      7496 non-null   object
#  1   availability   7496 non-null   object
#  2   size           7496 non-null   object
#  3   society        7496 non-null   object
#  4   total_sqft     7496 non-null   object
#  5   bath           7496 non-null   float64
#  6   balcony        7496 non-null   float64
#  7   price          7496 non-null   float64
#  8   site_location  7496 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 585.6+ KB

# %%
df["area_type"]
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 3        Super built-up  Area
# 5        Super built-up  Area
# 11                 Plot  Area
#                  ...
# 13313    Super built-up  Area
# 13314    Super built-up  Area
# 13315          Built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# Name: area_type, Length: 7496, dtype: object

# %%
a=list(df["area_type"])

# %%
a=set(a)

# %%
a
# Out:
# {'Built-up  Area', 'Carpet  Area', 'Plot  Area', 'Super built-up  Area'}

# %%
df["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df["area_type"].value_counts()
# Out:
# Super built-up  Area    6017
# Built-up  Area          1158
# Plot  Area               269
# Carpet  Area              52
# Name: area_type, dtype: int64

# %%
df['area_type']=df['area_type'].replace(['Super built-up  Area'],0)
df['area_type']=df['area_type'].replace(['Built-up  Area'],1)
df['area_type']=df['area_type'].replace(['Plot  Area '],2)
df['area_type']=df['area_type'].replace(['Carpet  Area'],3)

# %%
df["area_type"].value_counts()
# Out:
# 0             6017
# 1             1158
# Plot  Area     269
# 3               52
# Name: area_type, dtype: int64

# %%
df.drop(['availability'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7496 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      7496 non-null   object
#  1   size           7496 non-null   object
#  2   society        7496 non-null   object
#  3   total_sqft     7496 non-null   object
#  4   bath           7496 non-null   float64
#  5   balcony        7496 non-null   float64
#  6   price          7496 non-null   float64
#  7   site_location  7496 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 527.1+ KB

# %%
df["area_type"].value_counts()
# Out:
# 0             6017
# 1             1158
# Plot  Area     269
# 3               52
# Name: area_type, dtype: int64

# %%
df['size']=df['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df
# Out:
#         area_type  size  society total_sqft  bath  balcony   price  \
# 0               0     2  Coomee        1056   2.0      1.0   39.07
# 1      Plot  Area     4  Theanmp       2600   5.0      3.0  120.00
# 3               0     3  Soiewre       1521   3.0      1.0   95.00
# 5               0     2  DuenaTa       1170   2.0      1.0   38.00
# 11     Plot  Area     4  Prrry M       2785   5.0      3.0  295.00
# ...           ...   ...      ...        ...   ...      ...     ...
# 13313           0     3  Aklia R       1345   2.0      1.0   57.00
# 13314           0     3  SoosePr       1715   3.0      3.0  112.00
# 13315           1     5  ArsiaEx       3453   4.0      0.0  231.00
# 13317           1     2  Mahla T       1141   2.0      1.0   60.00
# 13318           0     4  SollyCl       4689   4.0      1.0  488.00
#
#          site_location
# 0          Alandi Road
# 1      Ambegaon Budruk
# 3                Aundh
# 5         Balaji Nagar
# 11              Bopodi
# ...

# %%
def isFloat(x):
    try:
        float(x)
    except:
        return False
    return True
df[~df['total_sqft'].apply(isFloat)]
# Out:
#       area_type  size  society   total_sqft  bath  balcony    price  \
# 30            0     4  LedorSa  2100 - 2850   4.0      0.0  186.000
# 122           0     4  SNontle  3067 - 8156   4.0      0.0  477.000
# 137           0     2  Vaarech  1042 - 1105   2.0      0.0   54.005
# 165           0     2  Kinuerg  1145 - 1340   2.0      0.0   43.490
# 188           0     2  MCvarar  1015 - 1540   2.0      0.0   56.800
# ...         ...   ...      ...          ...   ...      ...      ...
# 12975         0     2  Bhath N   850 - 1060   2.0      0.0   38.190
# 12990         0     3  Sodgere  1804 - 2273   3.0      0.0  122.000
# 13059         0     2  Shodsir  1200 - 1470   2.0      0.0   72.760
# 13265         0     2  Ranuetz  1133 - 1384   2.0      0.0   59.135
# 13299         0     4  Prtates  2830 - 2882   5.0      0.0  154.500
#
#        site_location
# 30          Gultekdi
# 122      Ganeshkhind
# 137          Khadaki
# 165     Prabhat Road
# 188       Wakadewadi
# ...

# %%
def convert_sqft_to_num(x):
    tokens=x.split('-')
    if len(tokens)==2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None
df['new_total_sqft']=df.total_sqft.apply(convert_sqft_to_num)
df=df.drop('total_sqft',axis='columns')
df.head()
# Out:
#      area_type  size  society  bath  balcony   price    site_location  \
# 0            0     2  Coomee    2.0      1.0   39.07      Alandi Road
# 1   Plot  Area     4  Theanmp   5.0      3.0  120.00  Ambegaon Budruk
# 3            0     3  Soiewre   3.0      1.0   95.00            Aundh
# 5            0     2  DuenaTa   2.0      1.0   38.00     Balaji Nagar
# 11  Plot  Area     4  Prrry M   5.0      3.0  295.00           Bopodi
#
#     new_total_sqft
# 0           1056.0
# 1           2600.0
# 3           1521.0
# 5           1170.0
# 11          2785.0

# %%
final=pd.get_dummies(df)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7496 entries, 0 to 13318
# Columns: 2698 entries, size to site_location_other
# dtypes: float64(4), int64(1), uint8(2693)
# memory usage: 19.6 MB

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3],"r");  # Plot some data on the axes.

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b');

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(0,21)],[i*2+3 for i in range(0,21)])
plt.xlabel('techsnap')
plt.ylabel('working hours')

plt.show()
